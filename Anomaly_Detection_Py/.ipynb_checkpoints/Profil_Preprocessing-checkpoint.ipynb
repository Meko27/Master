# %%
# %matplotlib inline
import cv2 
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import os
from skimage.filters import threshold_otsu
from skimage import exposure, img_as_float, img_as_ubyte
from scipy import ndimage
from PIL import Image
import time
from scipy.ndimage.measurements import label

# %%
# read image
path = '/Users/meko/Downloads/Technoform_profiles/Profil_1/'
im_id = 'Basler_acA3088-57uc__23186829__20200218_120749566_1.bmp'
img = cv2.imread(path + im_id)

img_g = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) # to gray
crop_boung_x = 200
crop_bound_y = 500
img_g_crop = img_g[500:-500,200:-200]
print('shape: ', img_g_crop.shape)
# Out:
# shape:  (1064, 2688)

# %%
plt.imshow(img)
plt.title('original')
plt.show();

# %%
# Cont1

img_cont1 = np.zeros((img_g_crop.shape[0],img_g_crop.shape[1]),dtype = 'uint8')

alpha = 2
beta = 20
start2 = time.time()
print('start loop')
for i in range(img_g_crop.shape[0]):
    for j in range(img_g_crop.shape[1]):
       img_cont1[i,j] = np.clip(alpha*img_g_crop[i,j]+beta,0,255)
end2 = time.time()
print('loop2: ', end2-start2)
# Out:
# start loop
# loop2:  74.56235003471375

# %%
# Cont2

# Contrast stretching according to the script
a = 0.15
b = 0.65
sa = 0.3
sb = 0.9

imgU8 = img_g_crop       # required for fancy indexing cdf[imgU8] later
img = img_as_float(img_g_crop)  # Scale into range [0, 1] of float

mask_left = (img < a)
mask_center = ((img >= a) & (img < b))  
mask_right = (img >= b)

img_cont2 = np.copy(img)          
img_cont2[mask_left]   = img[mask_left] * sa / a
img_cont2[mask_center] = sa + (img[mask_center]-a) * (sb - sa) / (b - a)
img_cont2[mask_right] = sb + (img[mask_right]-b) * (1. - sb) / (1. - b)

# %%
# Cont3
img_cont3 = exposure.adjust_gamma(img_g_crop, 2)

# %%
plt.figure(1)
plt.imshow(img_g_crop,cmap='gray')
plt.title('org_img')
plt.figure(2)
plt.imshow(img_cont1, cmap='gray')
plt.title('Cont1')
plt.figure(4)
plt.imshow(img_as_ubyte(img_cont2), cmap='gray')
plt.title('Cont2')
plt.show();
plt.imshow(img_as_ubyte(img_cont3), cmap='gray')
plt.title('Cont3')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-ba17aa580b04> in <module>
#       9 plt.title('Cont2')
#      10 plt.show();
# ---> 11 plt.imshow(img_as_ubyte(img_cont3), cmap='gray')
#      12 plt.title('Cont3')
#      13 plt.show();
#
# NameError: name 'img_cont3' is not defined

# %%
np.max(img_cont2)
# Out:
# 0.9137254901960784

# %%
# Naive Edge Detection
filter_len = 100
filter_wid = 5
kernel = np.ones((filter_len,filter_wid), dtype=np.uint8)
img_mid = img_cont2.shape[1]//2
pixel_pos = []
for i in range(filter_wid//2 + 1 , img_cont2.shape[1] - filter_wid//2):
    result = kernel * img_cont2[img_mid - filter_len//2 : img_mid + filter_len//2 , i-filter_wid//2 : i+filter_wid//2 + 1 ]
    if np.sum(result) < filter_len*filter_wid*200:
        pixel_pos.append(i)
bound_left = pixel_pos[0] + crop_bound_x - 10
bound_right = pixel_pos[-1] + crop_bound_x + 10
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-bcd19c042743> in <module>
#       6 pixel_pos = []
#       7 for i in range(filter_wid//2 + 1 , img_cont2.shape[1] - filter_wid//2):
# ----> 8     result = kernel * img_cont2[img_mid - filter_len//2 : img_mid + filter_len//2 , i-filter_wid//2 : i+filter_wid//2 + 1 ]
#       9     if np.sum(result) < filter_len*filter_wid*200:
#      10         pixel_pos.append(i)
#
# ValueError: operands could not be broadcast together with shapes (100,5) (0,5)

# %%
######Canny EDGE DETECTION######

edges = cv2.Canny(img_as_ubyte(img_cont2),20,60,apertureSize = 3)
print(edges.shape)

kernel = np.array([[0,1,2,1,0], 
                    [0,1,2,1,0], 
                    [0,1,2,1,0], 
                    [0,1,2,1,0], 
                    [0,1,2,1,0],
                    [0,1,2,1,0],
                    [0,1,0,1,0],
                    [0,1,2,1,0],
                    [0,1,2,1,0],
                    [0,1,2,1,0],
                    [0,1,2,1,0],
                    [0,1,2,1,0],
                    [0,1,2,1,0]])

kernel = kernel[2:-2,:]
kernel_r = kernel.shape[0] # =9
kernel_c = kernel.shape[1] # =5
edges2 = np.zeros(img_g_crop.shape)
print('start loop')
for i in range((kernel_r-1)//2,img_g_crop.shape[0]-(kernel_r-1)//2 -1):
    for j in range((kernel_c-1)//2,img_g_crop.shape[1]-(kernel_c-1)//2 -1):
        end_j = j + ((kernel_c-1)//2 +1)
        start_j = j-(kernel_c-1)//2
        local_pixels = edges[i-(kernel_r-1)//2:i+(kernel_r-1)//2 + 1 , start_j : end_j]
        result = local_pixels * kernel
        a=np.sum(result)
        edges2[i,j] = np.sum(result)
        #if edges2[i,j] < 1500:
        #    edges2[i,j] = 0
print('end loop')
plt.figure(2)
plt.imshow(edges2,cmap='gray')
plt.title('edges2')

plt.imshow(edges, cmap='gray')
plt.show()
# Out:
# (1064, 2688)

# %%
#####Detect Object####

# Hough transform
rho = 1
theta = np.pi/(180)   
threshold = 200
edges2 = np.uint8(edges2)
lines = cv2.HoughLines(edges2,rho,theta,threshold)
print(lines.shape)

for rho,theta in lines[i]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    cv2.line(img_g_crop,(x1,y1),(x2,y2),(255,255,255),20)

cv2.imwrite('linesn.jpg',img)
lines_i = cv2.imread('linesn.jpg')
plt.figure(2)
plt.imshow(lines_i)
# Out:
# (21672, 1, 2)

# %%
edges2_d = cv2.fastNlMeansDenoising(edges2,h=1000)
plt.imshow(edges2_d)
