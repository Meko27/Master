# %%
# %matplotlib inline
import cv2 
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
from PIL import Image
import os
from skimage.filters import threshold_otsu
from skimage import exposure, img_as_float, img_as_ubyte
from scipy import ndimage
from PIL import Image
import time
from scipy.ndimage.measurements import label

# %%
def strech_contrast(img,A=0.15,B=0.65,SA=0.3,SB=0.9):
    # Stech Contrast of Grayscale Image

    img_float = img_as_float(img)  # Scale into range [0, 1] of float

    mask_left = (img_float < A)
    mask_center = ((img_float >= A) & (img_float < B))  
    mask_right = (img_float >= B)

    img_cont = np.copy(img_float)          
    img_cont[mask_left]   = img_float[mask_left] * SA / A
    img_cont[mask_center] = SA + (img_float[mask_center]-A) * (SB - SA) / (B - A)
    img_cont[mask_right] = SB + (img_float[mask_right]-B) * (1. - SB) / (1. - B)
    img_cont = img_as_ubyte(img_cont)
    
    return img_cont

# %%
def detect_object(img , FILTER_LEN=800 , FILTER_WID=5):
    # Detect Objectbounds
    kernel = np.ones((FILTER_LEN,FILTER_WID), dtype=np.uint8)
    img_centery = img.shape[0]//2 # vertical img center
    pixel_pos = []
    for i in range(FILTER_WID//2 + 1 , img.shape[1] - FILTER_WID//2):
        result = kernel * img[img_centery - FILTER_LEN//2 : img_centery + FILTER_LEN//2 , i-FILTER_WID//2 : i+FILTER_WID//2 + 1 ]
        if np.sum(result) < FILTER_WID*FILTER_LEN*200:
            pixel_pos.append(i)            
    edge_left = pixel_pos[0] - 10
    edge_right = pixel_pos[-1] + 10
    
    return (edge_left,edge_right)

# %%
# read image
img_list = []
path = '/Users/meko/Downloads/Technoform_profiles/'
im_id1 = 'Profil_1/Basler_acA3088-57uc__23186829__20200218_120749566_1.bmp'
im_id2 = 'Profil_2/Basler_acA3088-57uc__23186829__20200218_121016407_9.bmp'
im_id3 = 'Profil_3/Basler_acA3088-57uc__23186829__20200218_121314356_9.bmp'
im_id4 = 'Profil_4/Basler_acA3088-57uc__23186829__20200218_121432108_7.bmp'

img_list.append(cv2.imread(path + im_id1))
img_list.append(cv2.imread(path + im_id2))
img_list.append(cv2.imread(path + im_id3))
img_list.append(cv2.imread(path + im_id4))

# %%
# Convert to grayscale
img_g_crop_list = []
for img in img_list:
    img_g = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) # to gray
    CROP_BOUNDX = 300
    CROP_BOUNDY = 300
    img_g_crop = img_g[CROP_BOUNDY:-CROP_BOUNDY,CROP_BOUNDX:-CROP_BOUNDX]
    img_g_crop_list.append(img_g_crop)
    print('shape: ', img_g_crop.shape)
# Out:
# shape:  (1464, 2488)
# shape:  (1464, 2488)
# shape:  (1464, 2488)
# shape:  (1464, 2488)

# %%
# Contrast Streching
img_g_cont_list = []
for img in img_g_crop_list:
    img_g_cont = strech_contrast(img)
    img_g_cont_list.append(img_g_cont)
# Out:
# 4

# %%
# Detect Object
width_sum = 0
edges_list = []
for img in img_g_cont_list:
    edges_list.append(detect_object(img))
    width = edges[1]-edges[0]
    width_sum += width
# Out:
# 4

# %%
# Cut out Object
img_out_list = []
for i,img in enumerate(img_list):
    img_out = img[:,edges_list[i][0]+CROP_BOUNDX:edges_list[i][1]+CROP_BOUNDX,:]
    img_out_list.append(img_out)
    print(img_out.shape)
# Out:
# (2064, 998, 3)
# (2064, 993, 3)
# (2064, 1321, 3)
# (2064, 1195, 3)

# %%
# Adjust Contrast
CLIP_LIMIT = 0.015
img_outf_list = []
for img in img_out_list:
    img_out = exposure.equalize_adapthist(img,clip_limit = CLIP_LIMIT) 
    img_out = img_as_ubyte(img_out) # equalize_adapthist converst image to float64
    img_outf_list.append(img_out)

# %%
for img in img_outf_list:
    plt.imshow(img)
    plt.show()

# %%
# Cut out AOI
img_out_aoi_list = []
for img in img_outf_list:
    img_out_aoi = img[500:1500,:,:]
    img_out_aoi_list.append(img_out_aoi)
    plt.imshow(img_out_aoi)
    plt.show()

# %%
# Mean width
width_mean = width_sum//len(img_list)

# %%
# Resize
RESIZE_FACTOR = 0.5
img_out_aoi_r_list = []
for img in img_out_aoi_list:
    height = img.shape[0]
    img_out = cv2.resize(img,(int(width_mean*RESIZE_FACTOR) , int(height*RESIZE_FACTOR)))
    img_out_aoi_r_list.append(img_out)
    plt.imshow(img_out)
    plt.show()

# %%
fig,ax = plt.subplots(1)
ax.imshow(img_out_aoi_r_list[0])
rect = patches.Rectangle((0,0),128,128,linewidth=1,edgecolor='r',facecolor='none')
ax.add_patch(rect)
plt.show()

# %%
# Cont4
img_cont4 = exposure.equalize_adapthist(img_g_crop,clip_limit=0.015)

# %%
plt.figure(1)
plt.imshow(img_g_crop,cmap='gray')
plt.title('org_img')
plt.figure(2)
plt.imshow(img_cont1, cmap='gray')
plt.title('Cont1')
plt.figure(4)
plt.imshow(img_as_ubyte(img_cont2), cmap='gray')
plt.title('Cont2')
plt.show();
plt.imshow(img_as_ubyte(img_cont3), cmap='gray')
plt.title('Cont3')
plt.show();
plt.imshow(img_as_ubyte(img_cont4), cmap='gray')
plt.title('Cont4')
plt.show();

# %%
# Out:
# 0.9137254901960784

# %%
# Naive Edge Detection
filter_len = 100
filter_wid = 5
kernel = np.ones((filter_len,filter_wid), dtype=np.uint8)
img_mid = img_cont2.shape[1]//2
pixel_pos = []
for i in range(filter_wid//2 + 1 , img_cont2.shape[1] - filter_wid//2):
    result = kernel * img_cont2[img_mid - filter_len//2 : img_mid + filter_len//2 , i-filter_wid//2 : i+filter_wid//2 + 1 ]
    if np.sum(result) < filter_len*filter_wid*200:
        pixel_pos.append(i)
bound_left = pixel_pos[0] + crop_bound_x - 10
bound_right = pixel_pos[-1] + crop_bound_x + 10
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-bcd19c042743> in <module>
#       6 pixel_pos = []
#       7 for i in range(filter_wid//2 + 1 , img_cont2.shape[1] - filter_wid//2):
# ----> 8     result = kernel * img_cont2[img_mid - filter_len//2 : img_mid + filter_len//2 , i-filter_wid//2 : i+filter_wid//2 + 1 ]
#       9     if np.sum(result) < filter_len*filter_wid*200:
#      10         pixel_pos.append(i)
#
# ValueError: operands could not be broadcast together with shapes (100,5) (0,5)

# %%
######Canny EDGE DETECTION######

edges = cv2.Canny(img_as_ubyte(img_cont2),20,60,apertureSize = 3)
print(edges.shape)

kernel = np.array([[0,1,2,1,0], 
                    [0,1,2,1,0], 
                    [0,1,2,1,0], 
                    [0,1,2,1,0], 
                    [0,1,2,1,0],
                    [0,1,2,1,0],
                    [0,1,0,1,0],
                    [0,1,2,1,0],
                    [0,1,2,1,0],
                    [0,1,2,1,0],
                    [0,1,2,1,0],
                    [0,1,2,1,0],
                    [0,1,2,1,0]])

kernel = kernel[2:-2,:]
kernel_r = kernel.shape[0] # =9
kernel_c = kernel.shape[1] # =5
edges2 = np.zeros(img_g_crop.shape)
print('start loop')
for i in range((kernel_r-1)//2,img_g_crop.shape[0]-(kernel_r-1)//2 -1):
    for j in range((kernel_c-1)//2,img_g_crop.shape[1]-(kernel_c-1)//2 -1):
        end_j = j + ((kernel_c-1)//2 +1)
        start_j = j-(kernel_c-1)//2
        local_pixels = edges[i-(kernel_r-1)//2:i+(kernel_r-1)//2 + 1 , start_j : end_j]
        result = local_pixels * kernel
        a=np.sum(result)
        edges2[i,j] = np.sum(result)
        #if edges2[i,j] < 1500:
        #    edges2[i,j] = 0
print('end loop')
plt.figure(2)
plt.imshow(edges2,cmap='gray')
plt.title('edges2')

plt.imshow(edges, cmap='gray')
plt.show()
# Out:
# (1064, 2688)

# %%
#####Detect Object####

# Hough transform
rho = 1
theta = np.pi/(180)   
threshold = 200
edges2 = np.uint8(edges2)
lines = cv2.HoughLines(edges2,rho,theta,threshold)
print(lines.shape)

for rho,theta in lines[i]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    cv2.line(img_g_crop,(x1,y1),(x2,y2),(255,255,255),20)

cv2.imwrite('linesn.jpg',img)
lines_i = cv2.imread('linesn.jpg')
plt.figure(2)
plt.imshow(lines_i)
# Out:
# (21672, 1, 2)

# %%
edges2_d = cv2.fastNlMeansDenoising(edges2,h=1000)
plt.imshow(edges2_d)
