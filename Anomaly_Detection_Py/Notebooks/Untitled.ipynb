# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
path_anomal = '/Users/meko/Documents/Repos/Master/Anomaly_Detection_Py/data/carpet/test/hole'
img = '/000.png'
path = path_anomal + img

img = cv2.imread(path)
dim = (512,512)
img_r = cv2.resize(img,dim)

# %%
fig,ax = plt.subplots(1)
ax.imshow(img_r)
rect = patches.Rectangle((0,0),128,128,linewidth=1,edgecolor='r',facecolor='none')
ax.add_patch(rect)
plt.show()
